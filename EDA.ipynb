# %%
import pandas as pd
import numpy as np
import seaborn as sns
import math
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
raw_df = pd.read_csv('Life Expectancy Data.csv')
df = raw_df.copy()
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0    6.0               8.16         65.0        0.1  584.259210  33736494.0
# 1   58.0               8.18         62.0        0.1  612.696514    327582.0
# 2   62.0               8.13         64.0        0.1  631.744976  31731688.0
# 3   67.0               8.52         67.0        0.1  669.959000   3696958.0
# 4   68.0               7.87         68.0        0.1   63.537231   2978599.0
#
#     thinness  1-19 years   thinness 5-9 years  \
# 0                   17.2                 17.3
# 1                   17.5                 17.5
# 2                   17.7                 17.7
# 3                   17.9                 18.0
# 4                   18.2                 18.2
#
#    Income composition of resources  Schooling
# 0                            0.479       10.1
# 1                            0.476       10.0
# 2                            0.470        9.9
# 3                            0.463        9.8
# 4                            0.454        9.5
#
# [5 rows x 22 columns]

# %%
df.shape
# Out:
# (2938, 22)

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip()
df.columns = df.columns.str.replace(' ','_').str.replace('-','_')

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life_expectancy', 'Adult_Mortality',
#        'infant_deaths', 'Alcohol', 'percentage_expenditure', 'Hepatitis_B',
#        'Measles', 'BMI', 'under_five_deaths', 'Polio', 'Total_expenditure',
#        'Diphtheria', 'HIV/AIDS', 'GDP', 'Population', 'thinness__1_19_years',
#        'thinness_5_9_years', 'Income_composition_of_resources', 'Schooling'],
#       dtype='object')

# %%
len(df['Country'].unique())
# Out:
# 193

# %% [markdown]
# Data Imputing

# %%
df.isna().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life_expectancy                     10
# Adult_Mortality                     10
# infant_deaths                        0
# Alcohol                            194
# percentage_expenditure               0
# Hepatitis_B                        553
# Measles                              0
# BMI                                 34
# under_five_deaths                    0
# Polio                               19
# Total_expenditure                  226
# Diphtheria                          19
# HIV/AIDS                             0
# GDP                                448
# Population                         652
# thinness__1_19_years                34
# thinness_5_9_years                  34
# Income_composition_of_resources    167
# Schooling                          163
# dtype: int64

# %%
df.BMI.mean()
# Out:
# 38.32124655647373

# %%
df[df.BMI == 0]
# Out:
# Empty DataFrame
# Columns: [Country, Year, Status, Life_expectancy, Adult_Mortality, infant_deaths, Alcohol, percentage_expenditure, Hepatitis_B, Measles, BMI, under_five_deaths, Polio, Total_expenditure, Diphtheria, HIV/AIDS, GDP, Population, thinness__1_19_years, thinness_5_9_years, Income_composition_of_resources, Schooling]
# Index: []
#
# [0 rows x 22 columns]

# %%
# df.BMI.fillna(value=0,inplace=True)

# %%
BMI_lst = []
for country in df.Country.unique():
    temp_df = df[df.Country == country]
    
    for index, row in temp_df.iterrows():
        if row.BMI == 0 or row.BMI == np.nan:
            BMI_lst.append(temp_df.BMI.mean())
        else:
            BMI_lst.append(row.BMI)

# %%
BMI_lst
# Out:
# [19.1,
#  18.6,
#  18.1,
#  17.6,
#  17.2,
#  16.7,
#  16.2,
#  15.7,
#  15.2,
#  14.7,
#  14.2,
#  13.8,
#  13.4,
#  13.0,
#  12.6,
#  12.2,
#  58.0,
#  57.2,
#  56.5,
#  55.8,
#  55.1,
#  54.3,
#  53.5,
#  52.6,
#  51.7,
#  5.8,
#  49.9,
#  48.9,
#  47.9,
#  46.9,
#  46.0,
#  45.0,
#  59.5,
#  58.4,
#  57.2,
#  56.1,
#  55.0,
#  53.9,
#  52.8,
#  51.8,
#  5.8,
#  49.8,
#  48.9,
#  47.9,
#  47.0,
#  46.1,
#  45.3,
#  44.4,
#  23.3,
#  22.7,
#  22.1,
#  21.5,
#  21.0,
#  2.4,
#  19.8,
#  19.3,
#  18.8,
#  18.2,
#  17.7,
#  17.2,
#  16.8,
#  16.3,
#  15.8,
#  15.4,
#  47.7,
#  47.0,
#  46.4,
#  45.7,
#  45.1,
#  44.4,
#  43.8,
#  43.2,
#  42.6,
#  42.0,
#  41.4,
#  4.8,
#  4.1,
#  39.5,
#  38.9,
#  38.2,
#  62.8,
#  62.2,
#  61.6,
#  61.0,
#  6.4,
#  59.8,
#  59.2,
#  58.6,
#  58.0,
#  57.5,
#  56.9,
#  56.3,
#  55.7,
#  55.1,
#  54.6,
#  54.0,
#  54.9,
#  54.1,
#  53.3,
#  52.6,
#  51.9,
#  51.2,
#  5.7,
#  5.1,
#  49.7,
#  49.2,
#  48.8,
#  48.4,
#  48.1,
#  47.8,
#  47.4,
#  47.1,
#  66.6,
#  66.1,
#  65.5,
#  65.0,
#  64.4,
#  63.9,
#  63.4,
#  62.9,
#  62.5,
#  62.0,
#  61.5,
#  6.9,
#  6.3,
#  59.6,
#  59.0,
#  58.2,
#  57.6,
#  57.1,
#  56.6,
#  56.1,
#  55.7,
#  55.2,
#  54.7,
#  54.2,
#  53.7,
#  53.2,
#  52.7,
#  52.2,
#  51.7,
#  51.2,
#  5.6,
#  5.1,
#  52.5,
#  51.5,
#  5.6,
#  49.7,
#  48.8,
#  48.0,
#  47.3,
#  46.6,
#  45.9,
#  45.3,
#  44.7,
#  44.2,
#  43.6,
#  43.1,
#  42.6,
#  42.1,
#  64.5,
#  63.8,
#  63.2,
#  62.6,
#  62.0,
#  61.3,
#  6.7,
#  6.1,
#  59.4,
#  58.7,
#  58.1,
#  57.4,
#  56.7,
#  56.0,
#  55.2,
#  54.4,
#  63.6,
#  62.9,
#  62.2,
#  61.5,
#  6.8,
#  6.1,
#  59.3,
#  58.5,
#  57.6,
#  56.8,
#  56.1,
#  55.6,
#  55.2,
#  55.0,
#  54.8,
#  54.5,
#  18.3,
#  17.7,
#  17.0,
#  16.4,
#  15.8,
#  15.2,
#  14.6,
#  14.0,
#  13.5,
#  13.0,
#  12.5,
#  12.0,
#  11.6,
#  11.2,
#  1.8,
#  1.4,
#  54.5,
#  53.7,
#  53.0,
#  52.2,
#  51.4,
#  5.7,
#  49.9,
#  49.2,
#  48.4,
#  47.7,
#  46.9,
#  46.2,
#  45.4,
#  44.6,
#  43.8,
#  43.0,
#  62.3,
#  61.7,
#  61.1,
#  6.5,
#  59.9,
#  59.3,
#  58.7,
#  58.2,
#  57.7,
#  57.2,
#  56.7,
#  56.2,
#  55.8,
#  55.3,
#  54.9,
#  54.4,
#  63.7,
#  63.4,
#  63.0,
#  62.6,
#  62.3,
#  61.9,
#  61.6,
#  61.3,
#  6.9,
#  6.6,
#  6.2,
#  59.8,
#  59.4,
#  59.0,
#  58.5,
#  58.1,
#  5.9,
#  5.1,
#  49.3,
#  48.5,
#  47.8,
#  47.0,
#  46.3,
#  45.7,
#  45.0,
#  44.4,
#  43.8,
#  43.2,
#  42.6,
#  42.0,
#  41.4,
#  4.8,
#  25.7,
#  25.2,
#  24.6,
#  24.1,
#  23.5,
#  23.0,
#  22.5,
#  22.0,
#  21.5,
#  21.0,
#  2.5,
#  2.1,
#  19.7,
#  19.2,
#  18.8,
#  18.4,
#  24.5,
#  23.6,
#  22.7,
#  21.9,
#  21.1,
#  2.3,
#  19.5,
#  18.8,
#  18.0,
#  17.4,
#  16.7,
#  16.1,
#  15.5,
#  14.9,
#  14.4,
#  13.9,
#  52.6,
#  51.9,
#  51.2,
#  5.6,
#  49.9,
#  49.3,
#  48.6,
#  48.0,
#  47.3,
#  46.7,
#  46.0,
#  45.4,
#  44.7,
#  44.0,
#  43.3,
#  42.6,
#  55.8,
#  55.3,
#  54.7,
#  54.2,
#  53.7,
#  53.1,
#  52.6,
#  52.1,
#  51.5,
#  51.0,
#  5.5,
#  49.9,
#  49.4,
#  48.8,
#  48.2,
#  47.6,
#  37.9,
#  37.3,
#  36.8,
#  36.2,
#  35.7,
#  35.2,
#  34.7,
#  34.2,
#  33.7,
#  33.2,
#  32.7,
#  32.2,
#  31.6,
#  31.1,
#  3.5,
#  29.9,
#  56.1,
#  55.3,
#  54.5,
#  53.6,
#  52.8,
#  52.0,
#  51.1,
#  5.3,
#  49.4,
#  48.6,
#  47.8,
#  46.9,
#  46.1,
#  45.3,
#  44.5,
#  43.7,
#  41.2,
#  4.2,
#  39.2,
#  38.2,
#  37.2,
#  36.2,
#  35.2,
#  34.2,
#  33.2,
#  32.2,
#  31.2,
#  3.1,
#  29.1,
#  28.0,
#  27.0,
#  26.1,
#  65.7,
#  65.1,
#  64.5,
#  63.9,
#  63.3,
#  62.7,
#  62.1,
#  61.5,
#  6.9,
#  6.3,
#  59.7,
#  59.1,
#  58.6,
#  58.1,
#  57.5,
#  57.0,
#  19.4,
#  18.8,
#  18.2,
#  17.7,
#  17.1,
#  16.6,
#  16.1,
#  15.6,
#  15.1,
#  14.6,
#  14.2,
#  13.7,
#  13.3,
#  12.9,
#  12.5,
#  12.2,
#  18.7,
#  18.2,
#  17.6,
#  17.1,
#  16.6,
#  16.1,
#  15.7,
#  15.2,
#  14.8,
#  14.5,
#  14.1,
#  13.8,
#  13.5,
#  13.3,
#  13.0,
#  12.8,
#  28.0,
#  27.4,
#  26.8,
#  26.2,
#  25.6,
#  25.0,
#  24.4,
#  23.8,
#  23.2,
#  22.6,
#  22.1,
#  21.5,
#  2.9,
#  2.4,
#  19.9,
#  19.4,
#  31.3,
#  3.5,
#  29.7,
#  29.0,
#  28.2,
#  27.5,
#  26.8,
#  26.2,
#  25.5,
#  24.9,
#  24.3,
#  23.7,
#  23.2,
#  22.6,
#  22.1,
#  21.5,
#  19.6,
#  18.9,
#  18.2,
#  17.6,
#  17.0,
#  16.4,
#  15.9,
#  15.3,
#  14.8,
#  14.3,
#  13.9,
#  13.5,
#  13.1,
#  12.8,
#  12.4,
#  12.1,
#  29.0,
#  28.4,
#  27.8,
#  27.2,
#  26.6,
#  26.0,
#  25.4,
#  24.9,
#  24.4,
#  23.8,
#  23.3,
#  22.8,
#  22.3,
#  21.8,
#  21.3,
#  2.9,
#  67.0,
#  66.4,
#  65.8,
#  65.3,
#  64.7,
#  64.1,
#  63.6,
#  63.0,
#  62.5,
#  61.9,
#  61.3,
#  6.6,
#  6.0,
#  59.3,
#  58.5,
#  57.8,
#  22.7,
#  22.1,
#  21.6,
#  21.2,
#  2.7,
#  2.2,
#  19.8,
#  19.4,
#  19.0,
#  18.6,
#  18.2,
#  17.9,
#  17.5,
#  17.2,
#  16.8,
#  16.5,
#  19.1,
#  18.7,
#  18.2,
#  17.9,
#  17.5,
#  17.1,
#  16.7,
#  16.4,
#  16.1,
#  15.7,
#  15.4,
#  15.1,
#  14.8,
#  14.4,
#  14.1,
#  13.9,
#  63.8,
#  63.1,
#  62.5,
#  61.8,
#  61.2,
#  6.6,
#  59.9,
#  59.3,
#  58.7,
#  58.1,
#  57.4,
#  56.8,
#  56.1,
#  55.4,
#  54.7,
#  54.0,
#  32.9,
#  31.9,
#  3.9,
#  3.0,
#  29.0,
#  28.1,
#  27.3,
#  26.5,
#  25.7,
#  24.9,
#  24.1,
#  23.4,
#  22.6,
#  21.9,
#  21.2,
#  2.5,
#  57.9,
#  57.2,
#  56.4,
#  55.7,
#  55.0,
#  54.2,
#  53.5,
#  52.8,
#  52.0,
#  51.3,
#  5.5,
#  49.8,
#  49.0,
#  48.2,
#  47.5,
#  46.7,
#  24.2,
#  23.7,
#  23.2,
#  22.6,
#  22.1,
#  21.6,
#  21.1,
#  2.6,
#  2.1,
#  19.6,
#  19.2,
#  18.8,
#  18.4,
#  18.0,
#  17.6,
#  17.3,
#  27.4,
#  26.8,
#  26.2,
#  25.6,
#  25.0,
#  24.5,
#  23.9,
#  23.3,
#  22.8,
#  22.3,
#  21.7,
#  21.2,
#  2.7,
#  2.3,
#  19.8,
#  19.3,
#  82.8,
#  6.5,
#  59.5,
#  58.5,
#  57.5,
#  56.5,
#  55.5,
#  54.4,
#  53.4,
#  52.4,
#  51.4,
#  5.3,
#  49.3,
#  48.3,
#  47.3,
#  46.4,
#  45.4,
#  63.7,
#  63.1,
#  62.5,
#  61.9,
#  61.3,
#  6.6,
#  6.0,
#  59.4,
#  58.7,
#  58.1,
#  57.5,
#  56.9,
#  56.3,
#  55.8,
#  55.2,
#  54.7,
#  61.4,
#  6.7,
#  59.9,
#  59.2,
#  58.4,
#  57.7,
#  56.9,
#  56.2,
#  55.4,
#  54.6,
#  53.8,
#  53.0,
#  52.1,
#  51.3,
#  5.4,
#  49.4,
#  6.3,
#  59.8,
#  59.2,
#  58.7,
#  58.3,
#  57.8,
#  57.3,
#  56.8,
#  56.3,
#  55.8,
#  55.3,
#  54.8,
#  54.3,
#  53.8,
#  53.3,
#  52.8,
#  66.1,
#  65.6,
#  65.1,
#  64.5,
#  64.0,
#  63.6,
#  63.1,
#  62.6,
#  62.2,
#  61.8,
#  61.3,
#  6.8,
#  6.4,
#  59.9,
#  59.4,
#  59.0,
#  32.9,
#  32.4,
#  31.8,
#  31.3,
#  3.8,
#  3.3,
#  29.7,
#  29.2,
#  28.7,
#  28.2,
#  27.7,
#  27.2,
#  26.7,
#  26.2,
#  25.7,
#  25.2,
#  21.6,
#  21.1,
#  2.6,
#  2.1,
#  19.6,
#  19.1,
#  18.6,
#  18.2,
#  17.8,
#  17.3,
#  16.9,
#  16.5,
#  16.1,
#  15.7,
#  15.3,
#  14.9,
#  58.8,
#  58.4,
#  58.1,
#  57.7,
#  57.4,
#  57.0,
#  56.6,
#  56.3,
#  55.9,
#  55.4,
#  55.0,
#  54.4,
#  53.9,
#  53.3,
#  52.8,
#  52.2,
#  35.0,
#  34.4,
#  33.8,
#  33.2,
#  32.7,
#  32.2,
#  31.7,
#  31.3,
#  3.9,
#  3.6,
#  3.2,
#  29.8,
#  29.4,
#  29.0,
#  28.6,
#  28.2,
#  58.4,
#  58.9,
#  57.9,
#  56.8,
#  55.8,
#  54.7,
#  53.6,
#  52.6,
#  51.5,
#  5.4,
#  49.3,
#  48.2,
#  47.2,
#  46.1,
#  45.1,
#  44.1,
#  43.1,
#  54.2,
#  53.5,
#  52.8,
#  52.1,
#  51.4,
#  5.7,
#  5.0,
#  49.3,
#  48.6,
#  47.9,
#  47.2,
#  46.5,
#  45.8,
#  45.1,
#  44.3,
#  43.6,
#  61.1,
#  6.2,
#  59.4,
#  58.6,
#  57.8,
#  57.0,
#  56.2,
#  55.5,
#  54.8,
#  54.2,
#  53.5,
#  52.9,
#  52.3,
#  51.8,
#  51.2,
#  5.7,
#  56.1,
#  55.4,
#  54.7,
#  54.1,
#  53.4,
#  52.8,
#  52.1,
#  51.4,
#  5.8,
#  5.1,
#  49.4,
#  48.6,
#  47.8,
#  47.0,
#  46.2,
#  45.3,
#  24.5,
#  24.0,
#  23.5,
#  23.0,
#  22.6,
#  22.1,
#  21.7,
#  21.3,
#  2.9,
#  2.5,
#  2.2,
#  19.8,
#  19.5,
#  19.1,
#  18.7,
#  18.3,
#  18.6,
#  18.0,
#  17.5,
#  17.0,
#  16.5,
#  16.0,
#  15.5,
#  15.1,
#  14.7,
#  14.3,
#  13.9,
#  13.6,
#  13.3,
#  13.1,
#  12.8,
#  12.6,
#  59.9,
#  59.4,
#  59.0,
#  58.5,
#  58.0,
#  57.6,
#  57.1,
#  56.7,
#  56.3,
#  55.9,
#  55.5,
#  55.2,
#  54.9,
#  54.6,
#  54.3,
#  54.0,
#  17.6,
#  17.2,
#  16.8,
#  16.4,
#  16.0,
#  15.6,
#  15.3,
#  14.9,
#  14.5,
#  14.2,
#  13.8,
#  13.5,
#  13.2,
#  12.9,
#  12.6,
#  12.3,
#  62.7,
#  61.9,
#  61.1,
#  6.2,
#  59.5,
#  58.7,
#  58.0,
#  57.3,
#  56.6,
#  55.9,
#  55.1,
#  54.2,
#  53.2,
#  52.2,
#  51.2,
#  5.2,
#  62.1,
#  61.7,
#  61.4,
#  61.0,
#  6.6,
#  6.2,
#  59.8,
#  59.4,
#  59.0,
#  58.6,
#  58.1,
#  57.6,
#  57.1,
#  56.6,
#  56.1,
#  55.5,
#  62.5,
#  62.0,
#  61.6,
#  61.1,
#  6.6,
#  6.1,
#  59.6,
#  59.1,
#  58.6,
#  58.0,
#  57.5,
#  57.0,
#  56.4,
#  55.8,
#  55.2,
#  54.6,
#  36.3,
#  35.8,
#  35.2,
#  34.6,
#  34.1,
#  33.5,
#  33.0,
#  32.4,
#  31.9,
#  31.4,
#  3.8,
#  3.3,
#  29.8,
#  29.2,
#  28.7,
#  28.1,
#  27.3,
#  26.7,
#  26.0,
#  25.4,
#  24.8,
#  24.1,
#  23.5,
#  22.8,
#  22.2,
#  21.5,
#  2.9,
#  2.3,
#  19.7,
#  19.1,
#  18.5,
#  18.0,
#  56.2,
#  55.3,
#  54.4,
#  53.6,
#  52.8,
#  52.0,
#  51.3,
#  5.5,
#  49.9,
#  49.2,
#  48.6,
#  48.1,
#  47.5,
#  47.0,
#  46.5,
#  46.0,
#  62.3,
#  61.9,
#  61.4,
#  6.9,
#  6.4,
#  59.9,
#  ...]

# %%
dummy_df = df.copy()

# %%
dummy_df['BMI'] = BMI_lst

# %%
dummy_df.isna().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life_expectancy                     10
# Adult_Mortality                     10
# infant_deaths                        0
# Alcohol                            194
# percentage_expenditure               0
# Hepatitis_B                        553
# Measles                              0
# BMI                                 34
# under_five_deaths                    0
# Polio                               19
# Total_expenditure                  226
# Diphtheria                          19
# HIV/AIDS                             0
# GDP                                448
# Population                         652
# thinness__1_19_years                34
# thinness_5_9_years                  34
# Income_composition_of_resources    167
# Schooling                          163
# dtype: int64

# %%
dummy_df[dummy_df.BMI == 0]
# Out:
#           Country  Year      Status  Life_expectancy  Adult_Mortality  \
# 1715       Monaco  2013  Developing              NaN              NaN
# 2216   San Marino  2013  Developing              NaN              NaN
# 2409  South Sudan  2015  Developing             57.3            332.0
# 2410  South Sudan  2014  Developing             56.6            343.0
# 2411  South Sudan  2013  Developing             56.4            345.0
# 2412  South Sudan  2012  Developing             56.0            347.0
# 2413  South Sudan  2011  Developing             55.4            355.0
# 2414  South Sudan  2010  Developing             55.0            359.0
# 2415  South Sudan  2009  Developing             54.3            369.0
# 2416  South Sudan  2008  Developing             53.6            377.0
# 2417  South Sudan  2007  Developing             53.1            381.0
# 2418  South Sudan  2006  Developing             52.5            383.0
# 2419  South Sudan  2005  Developing             51.9            383.0
# 2420  South Sudan  2004  Developing             51.4            383.0
# 2421  South Sudan  2003  Developing             58.0            383.0
# 2422  South Sudan  2002  Developing             52.0            382.0
# 2423  South Sudan  2001  Developing             49.6            381.0
# 2424  South Sudan  2000  Developing             48.9             38.0
# 2457        Sudan  2015  Developing             64.1            225.0
# 2458        Sudan  2014  Developing             63.8            229.0
# 2459        Sudan  2013  Developing             63.5            232.0
# 2460        Sudan  2012  Developing             63.2            235.0
# 2461        Sudan  2011  Developing             62.7            241.0
# 2462        Sudan  2010  Developing             62.5            243.0
# 2463        Sudan  2009  Developing             62.0            248.0
# 2464        Sudan  2008  Developing             61.8            251.0
# 2465        Sudan  2007  Developing             61.4            254.0
# 2466        Sudan  2006  Developing             61.0             26.0
# 2467        Sudan  2005  Developing             67.0            261.0
# 2468        Sudan  2004  Developing             59.7            278.0
# 2469        Sudan  2003  Developing             59.6            278.0
# 2470        Sudan  2002  Developing             59.4            277.0
# 2471        Sudan  2001  Developing             58.9            283.0
# 2472        Sudan  2000  Developing             58.6            284.0
#
#       infant_deaths  Alcohol  percentage_expenditure  Hepatitis_B  Measles  \
# 1715              0     0.01                0.000000         99.0        0
# 2216              0     0.01                0.000000         69.0        0
# 2409             26      NaN                0.000000         31.0      878
# 2410             26      NaN               46.074469          NaN      441
# 2411             26      NaN               47.444530          NaN      525
# 2412             26      NaN               38.338232          NaN     1952
# 2413             27      NaN                0.000000          NaN     1256
# 2414             27      NaN                0.000000          NaN        0
# 2415             27      NaN                0.000000          NaN        0
# 2416             27      NaN                0.000000          NaN        0
# 2417             27      NaN                0.000000          NaN        0
# 2418             28      NaN                0.000000          NaN        0
# 2419             28      NaN                0.000000          NaN        0
# 2420             29      NaN                0.000000          NaN        0
# 2421             29      NaN                0.000000          NaN        0
# 2422             30      NaN                0.000000          NaN        0
# 2423             30      NaN                0.000000          NaN        0
# 2424             31      NaN                0.000000          NaN        0
# 2457             58      NaN                0.000000         93.0     3585
# 2458             59     0.01              253.608651         94.0      676
# 2459             60     0.01              227.835321         93.0     2813
# 2460             61     0.01              220.522192         92.0     8523
# 2461             61     2.12              196.689215         93.0     5616
# 2462             62     1.77              172.009788         75.0      680
# 2463             63     1.99               17.053693         72.0       68
# 2464             64     2.01              128.636271         78.0      129
# 2465             65     2.01               86.131669         78.0      327
# 2466             66     1.90               60.336857          6.0      228
# 2467             66     1.55               37.590396         22.0     1374
# 2468             68     1.59               37.044800          NaN     9562
# 2469             69     1.74               35.352647          NaN     4381
# 2470             70     1.59               30.622875          NaN     4529
# 2471             71     1.81               28.880697          NaN     4362
# 2472             71     1.76               30.860010          NaN     2875
#
#       ...  Polio  Total_expenditure  Diphtheria  HIV/AIDS          GDP  \
# 1715  ...   99.0               4.30        99.0       0.1          NaN
# 2216  ...   69.0               6.50        69.0       0.1          NaN
# 2409  ...   41.0                NaN        31.0       3.4   758.725782
# 2410  ...   44.0               2.74        39.0       3.5  1151.861715
# 2411  ...    5.0               2.62        45.0       3.6  1186.113250
# 2412  ...   64.0               2.77        59.0       3.8   958.455810
# 2413  ...   66.0                NaN        61.0       3.9   176.971300
# 2414  ...    NaN                NaN         NaN       4.0  1562.239346
# 2415  ...    NaN                NaN         NaN       4.2  1264.789980
# 2416  ...    NaN                NaN         NaN       4.2  1678.711862
# 2417  ...    NaN                NaN         NaN       4.2          NaN
# 2418  ...    NaN                NaN         NaN       4.1          NaN
# 2419  ...    NaN                NaN         NaN       3.9          NaN
# 2420  ...    NaN                NaN         NaN       3.8          NaN
# 2421  ...    NaN                NaN         NaN       3.5          NaN
# 2422  ...    NaN                NaN         NaN       3.3          NaN
# 2423  ...    NaN                NaN         NaN       3.0          NaN
# 2424  ...    NaN                NaN         NaN       2.7          NaN
# 2457  ...   93.0                NaN        93.0       0.3  2513.884661
# 2458  ...   94.0               8.43        94.0       0.3  2176.898290
# 2459  ...   93.0               8.42        93.0       0.3  1955.667990
# 2460  ...   92.0               8.20        92.0       0.3  1892.894352
# 2461  ...   93.0               8.30        93.0       0.3  1666.857757
# 2462  ...    9.0               7.97         9.0       0.3  1476.478870
# 2463  ...   81.0               8.40        81.0       0.3  1226.884381
# 2464  ...   85.0               8.17        86.0       0.3  1291.528826
# 2465  ...   84.0               4.72        84.0       0.3  1115.695200
# 2466  ...   77.0               3.93        78.0       0.2   893.879364
# 2467  ...   78.0               3.18        78.0       0.2   679.753995
# 2468  ...   74.0               3.39        74.0       0.2   565.569459
# 2469  ...   69.0               3.18        69.0       0.2   477.738478
# 2470  ...    6.0               2.95         6.0       0.2   412.151756
# 2471  ...   66.0               2.96        66.0       0.2   377.525445
# 2472  ...   62.0               3.23        62.0       0.1   361.358430
#
#       Population  thinness__1_19_years  thinness_5_9_years  \
# 1715         NaN                   NaN                 NaN
# 2216         NaN                   NaN                 NaN
# 2409  11882136.0                   NaN                 NaN
# 2410   1153971.0                   NaN                 NaN
# 2411   1117749.0                   NaN                 NaN
# 2412   1818258.0                   NaN                 NaN
# 2413   1448857.0                   NaN                 NaN
# 2414    167192.0                   NaN                 NaN
# 2415    967667.0                   NaN                 NaN
# 2416   9263136.0                   NaN                 NaN
# 2417     88568.0                   NaN                 NaN
# 2418   8468152.0                   NaN                 NaN
# 2419    818877.0                   NaN                 NaN
# 2420   7787655.0                   NaN                 NaN
# 2421    751642.0                   NaN                 NaN
# 2422   7237276.0                   NaN                 NaN
# 2423   6974442.0                   NaN                 NaN
# 2424     67656.0                   NaN                 NaN
# 2457   3864783.0                   NaN                 NaN
# 2458  37737913.0                   NaN                 NaN
# 2459  36849918.0                   NaN                 NaN
# 2460   3599192.0                   NaN                 NaN
# 2461  35167314.0                   NaN                 NaN
# 2462  34385963.0                   NaN                 NaN
# 2463   3365619.0                   NaN                 NaN
# 2464  32955496.0                   NaN                 NaN
# 2465  32282526.0                   NaN                 NaN
# 2466    316764.0                   NaN                 NaN
# 2467   3911914.0                   NaN                 NaN
# 2468   3186341.0                   NaN                 NaN
# 2469  29435944.0                   NaN                 NaN
# 2470  28679565.0                   NaN                 NaN
# 2471    279455.0                   NaN                 NaN
# 2472   2725535.0                   NaN                 NaN
#
#       Income_composition_of_resources  Schooling
# 1715                              NaN        NaN
# 2216                              NaN       15.1
# 2409                            0.421        4.9
# 2410                            0.421        4.9
# 2411                            0.417        4.9
# 2412                            0.419        4.9
# 2413                            0.429        4.9
# 2414                            0.000        0.0
# 2415                            0.000        0.0
# 2416                            0.000        0.0
# 2417                            0.000        0.0
# 2418                            0.000        0.0
# 2419                            0.000        0.0
# 2420                            0.000        0.0
# 2421                            0.000        0.0
# 2422                            0.000        0.0
# 2423                            0.000        0.0
# 2424                            0.000        0.0
# 2457                            0.488        7.2
# 2458                            0.485        7.2
# 2459                            0.478        7.0
# 2460                            0.468        6.8
# 2461                            0.463        7.0
# 2462                            0.461        7.0
# 2463                            0.456        6.8
# 2464                            0.444        6.3
# 2465                            0.440        6.4
# 2466                            0.430        6.2
# 2467                            0.423        6.1
# 2468                            0.415        5.7
# 2469                            0.409        5.6
# 2470                            0.403        5.6
# 2471                            0.399        5.6
# 2472                            0.394        5.5
#
# [34 rows x 22 columns]

# %%
# df.fillna(value=0,inplace=True)

# %%
df.isna().sum()
# Out:
# Country                            0
# Year                               0
# Status                             0
# Life_expectancy                    0
# Adult_Mortality                    0
# infant_deaths                      0
# Alcohol                            0
# percentage_expenditure             0
# Hepatitis_B                        0
# Measles                            0
# BMI                                0
# under_five_deaths                  0
# Polio                              0
# Total_expenditure                  0
# Diphtheria                         0
# HIV/AIDS                           0
# GDP                                0
# Population                         0
# thinness__1_19_years               0
# thinness_5_9_years                 0
# Income_composition_of_resources    0
# Schooling                          0
# dtype: int64

# %%
df.dtypes
# Out:
# Country                             object
# Year                                 int64
# Status                              object
# Life_expectancy                    float64
# Adult_Mortality                    float64
# infant_deaths                        int64
# Alcohol                            float64
# percentage_expenditure             float64
# Hepatitis_B                        float64
# Measles                              int64
# BMI                                float64
# under_five_deaths                    int64
# Polio                              float64
# Total_expenditure                  float64
# Diphtheria                         float64
# HIV/AIDS                           float64
# GDP                                float64
# Population                         float64
# thinness__1_19_years               float64
# thinness_5_9_years                 float64
# Income_composition_of_resources    float64
# Schooling                          float64
# dtype: object

# %%
sns.countplot(data = df, x = 'Status')
# Out:
# <AxesSubplot:xlabel='Status', ylabel='count'>

# %%
df['Year'].unique()
# Out:
# array([2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005,
#        2004, 2003, 2002, 2001, 2000], dtype=int64)

# %%
polio_df = pd.DataFrame()

for country in df['Country'].unique():
    temp_df = df.loc[(df['Country'] == country)]
    temp_df = temp_df[temp_df['Polio'] == temp_df['Polio'].max()]
    if temp_df['Polio'].max() > 0:
        polio_df = polio_df.append(temp_df)
polio_df.head()
# Out:
#         Country  Year      Status  Life_expectancy  Adult_Mortality  \
# 4   Afghanistan  2011  Developing             59.2            275.0
# 16      Albania  2015  Developing             77.8             74.0
# 18      Albania  2013  Developing             77.2             84.0
# 19      Albania  2012  Developing             76.9             86.0
# 20      Albania  2011  Developing             76.6             88.0
#
#     infant_deaths  Alcohol  percentage_expenditure  Hepatitis_B  Measles  ...  \
# 4              71     0.01                7.097109         68.0     3013  ...
# 16              0     4.60              364.975229         99.0        0  ...
# 18              0     4.76              430.876979         99.0        0  ...
# 19              0     5.14              412.443356         99.0        9  ...
# 20              0     5.37              437.062100         99.0       28  ...
#
#     Polio  Total_expenditure  Diphtheria  HIV/AIDS          GDP  Population  \
# 4    68.0               7.87        68.0       0.1    63.537231   2978599.0
# 16   99.0               6.00        99.0       0.1  3954.227830     28873.0
# 18   99.0               5.66        99.0       0.1  4414.723140    289592.0
# 19   99.0               5.59        99.0       0.1  4247.614380      2941.0
# 20   99.0               5.71        99.0       0.1  4437.178680    295195.0
#
#     thinness__1_19_years  thinness_5_9_years  Income_composition_of_resources  \
# 4                   18.2                18.2                            0.454
# 16                   1.2                 1.3                            0.762
# 18                   1.3                 1.4                            0.759
# 19                   1.3                 1.4                            0.752
# 20                   1.4                 1.5                            0.738
#
#     Schooling
# 4         9.5
# 16       14.2
# 18       14.2
# 19       14.2
# 20       13.3
#
# [5 rows x 22 columns]

# %%
polio_df.shape
# Out:
# (596, 22)

# %%
polio_df.to_csv('Polio.csv')

# %%
polio_df.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life_expectancy', 'Adult_Mortality',
#        'infant_deaths', 'Alcohol', 'percentage_expenditure', 'Hepatitis_B',
#        'Measles', 'BMI', 'under_five_deaths', 'Polio', 'Total_expenditure',
#        'Diphtheria', 'HIV/AIDS', 'GDP', 'Population', 'thinness__1_19_years',
#        'thinness_5_9_years', 'Income_composition_of_resources', 'Schooling'],
#       dtype='object')

# %%
polio_df.drop(['Country','Year','Status','Schooling','Population',
               'GDP','Income_composition_of_resources','Total_expenditure'],
              inplace=True,
             axis =1)

# %%
polio_df.corr().abs()
# Out:
#                         Life_expectancy  Adult_Mortality  infant_deaths  \
# Life_expectancy                1.000000         0.329705       0.098445
# Adult_Mortality                0.329705         1.000000       0.144816
# infant_deaths                  0.098445         0.144816       1.000000
# Alcohol                        0.286686         0.071363       0.097704
# percentage_expenditure         0.247684         0.199070       0.096827
# Hepatitis_B                    0.051132         0.094085       0.014496
# Measles                        0.009087         0.014263       0.615620
# BMI                            0.188165         0.346274       0.220936
# under_five_deaths              0.121649         0.174439       0.992459
# Polio                          0.442664         0.345040       0.175362
# Diphtheria                     0.327917         0.281803       0.147035
# HIV/AIDS                       0.308992         0.609795       0.056328
# thinness__1_19_years           0.144383         0.269841       0.297296
# thinness_5_9_years             0.163109         0.302875       0.302879
#
#                          Alcohol  percentage_expenditure  Hepatitis_B  \
# Life_expectancy         0.286686                0.247684     0.051132
# Adult_Mortality         0.071363                0.199070     0.094085
# infant_deaths           0.097704                0.096827     0.014496
# Alcohol                 1.000000                0.301751     0.118420
# percentage_expenditure  0.301751                1.000000     0.063844
# Hepatitis_B             0.118420                0.063844     1.000000
# Measles                 0.020854                0.055438     0.022086
# BMI                     0.177909                0.133125     0.015367
# under_five_deaths       0.099069                0.098027     0.001012
# Polio                   0.225818                0.111030     0.321694
# Diphtheria              0.207951                0.105273     0.323000
# HIV/AIDS                0.023377                0.060470     0.031609
# thinness__1_19_years    0.422033                0.213485     0.129702
# thinness_5_9_years      0.394942                0.213953     0.118548
#
#                          Measles       BMI  under_five_deaths     Polio  \
# Life_expectancy         0.009087  0.188165           0.121649  0.442664
# Adult_Mortality         0.014263  0.346274           0.174439  0.345040
# infant_deaths           0.615620  0.220936           0.992459  0.175362
# Alcohol                 0.020854  0.177909           0.099069  0.225818
# percentage_expenditure  0.055438  0.133125           0.098027  0.111030
# Hepatitis_B             0.022086  0.015367           0.001012  0.321694
# Measles                 1.000000  0.120857           0.572139  0.019910
# BMI                     0.120857  1.000000           0.234856  0.188919
# under_five_deaths       0.572139  0.234856           1.000000  0.208017
# Polio                   0.019910  0.188919           0.208017  1.000000
# Diphtheria              0.032209  0.138134           0.175802  0.782767
# HIV/AIDS                0.021149  0.210101           0.079391  0.213893
# thinness__1_19_years    0.130651  0.444337           0.300564  0.142108
# thinness_5_9_years      0.118415  0.442268           0.309685  0.149668
#
#                         Diphtheria  HIV/AIDS  thinness__1_19_years  \
# Life_expectancy           0.327917  0.308992              0.144383
# Adult_Mortality           0.281803  0.609795              0.269841
# infant_deaths             0.147035  0.056328              0.297296
# Alcohol                   0.207951  0.023377              0.422033
# percentage_expenditure    0.105273  0.060470              0.213485
# Hepatitis_B               0.323000  0.031609              0.129702
# Measles                   0.032209  0.021149              0.130651
# BMI                       0.138134  0.210101              0.444337
# under_five_deaths         0.175802  0.079391              0.300564
# Polio                     0.782767  0.213893              0.142108
# Diphtheria                1.000000  0.125262              0.079514
# HIV/AIDS                  0.125262  1.000000              0.219246
# thinness__1_19_years      0.079514  0.219246              1.000000
# thinness_5_9_years        0.086155  0.262695              0.971507
#
#                         thinness_5_9_years
# Life_expectancy                   0.163109
# Adult_Mortality                   0.302875
# infant_deaths                     0.302879
# Alcohol                           0.394942
# percentage_expenditure            0.213953
# Hepatitis_B                       0.118548
# Measles                           0.118415
# BMI                               0.442268
# under_five_deaths                 0.309685
# Polio                             0.149668
# Diphtheria                        0.086155
# HIV/AIDS                          0.262695
# thinness__1_19_years              0.971507
# thinness_5_9_years                1.000000

# %%
plt.figure(figsize=(15,15))
sns.heatmap(polio_df.corr(),annot=True,cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(data=df,x='GDP',y = 'percentage_expenditure')
# Out:
# <AxesSubplot:xlabel='GDP', ylabel='percentage_expenditure'>

# %%
diseases = ['Hepatitis_B','Measles', 'Polio', 'Total_expenditure','Diphtheria',
            'HIV/AIDS', 'thinness__1_19_years','thinness_5_9_years']

max_disease_dict = {'Country' : [],
                   'Year' : [],
                   'Disease': [],
                   'Count' : []}


for country in df['Country'].unique():
    temp_df = df[df['Country'] == country]
    for year in temp_df['Year'].unique():
        temp_df = df.loc[(df['Country'] == country) & (df['Year'] == year)]
        
        disease_name = ''
        count = 0
        
        for disease in diseases:
            if temp_df[disease].values[0] >= count:
                count = temp_df[disease].values[0]
                disease_name = disease
            
        max_disease_dict['Country'].append(country)
        max_disease_dict['Year'].append(year)
        max_disease_dict['Disease'].append(disease_name)
        max_disease_dict['Count'].append(count)

# %%
disease_by_year_df = pd.DataFrame.from_dict(max_disease_dict)
disease_by_year_df.head()
# Out:
#        Country  Year  Disease   Count
# 0  Afghanistan  2015  Measles  1154.0
# 1  Afghanistan  2014  Measles   492.0
# 2  Afghanistan  2013  Measles   430.0
# 3  Afghanistan  2012  Measles  2787.0
# 4  Afghanistan  2011  Measles  3013.0

# %%
disease_by_year_df.to_csv('disease_by_year.csv')

# %%
print('minimum Life expectancy :',df.Life_expectancy.min())
print('maximum Life expectancy :',df.Life_expectancy.max())
print('minimum BMI :',df.BMI.min())
print('maximum BMI :',df.BMI.max())
# Out:
# minimum Life expectancy : 0.0
# maximum Life expectancy : 89.0
# minimum BMI : 0.0
# maximum BMI : 87.3

# %%
sns.scatterplot(data=df,x=df.BMI,y = df.Life_expectancy)
# Out:
# <AxesSubplot:xlabel='BMI', ylabel='Life_expectancy'>

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(),annot=True,cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %%
df[df.BMI == 0]
# Out:
#           Country  Year      Status  Life_expectancy  Adult_Mortality  \
# 1715       Monaco  2013  Developing              0.0              0.0
# 2216   San Marino  2013  Developing              0.0              0.0
# 2409  South Sudan  2015  Developing             57.3            332.0
# 2410  South Sudan  2014  Developing             56.6            343.0
# 2411  South Sudan  2013  Developing             56.4            345.0
# 2412  South Sudan  2012  Developing             56.0            347.0
# 2413  South Sudan  2011  Developing             55.4            355.0
# 2414  South Sudan  2010  Developing             55.0            359.0
# 2415  South Sudan  2009  Developing             54.3            369.0
# 2416  South Sudan  2008  Developing             53.6            377.0
# 2417  South Sudan  2007  Developing             53.1            381.0
# 2418  South Sudan  2006  Developing             52.5            383.0
# 2419  South Sudan  2005  Developing             51.9            383.0
# 2420  South Sudan  2004  Developing             51.4            383.0
# 2421  South Sudan  2003  Developing             58.0            383.0
# 2422  South Sudan  2002  Developing             52.0            382.0
# 2423  South Sudan  2001  Developing             49.6            381.0
# 2424  South Sudan  2000  Developing             48.9             38.0
# 2457        Sudan  2015  Developing             64.1            225.0
# 2458        Sudan  2014  Developing             63.8            229.0
# 2459        Sudan  2013  Developing             63.5            232.0
# 2460        Sudan  2012  Developing             63.2            235.0
# 2461        Sudan  2011  Developing             62.7            241.0
# 2462        Sudan  2010  Developing             62.5            243.0
# 2463        Sudan  2009  Developing             62.0            248.0
# 2464        Sudan  2008  Developing             61.8            251.0
# 2465        Sudan  2007  Developing             61.4            254.0
# 2466        Sudan  2006  Developing             61.0             26.0
# 2467        Sudan  2005  Developing             67.0            261.0
# 2468        Sudan  2004  Developing             59.7            278.0
# 2469        Sudan  2003  Developing             59.6            278.0
# 2470        Sudan  2002  Developing             59.4            277.0
# 2471        Sudan  2001  Developing             58.9            283.0
# 2472        Sudan  2000  Developing             58.6            284.0
#
#       infant_deaths  Alcohol  percentage_expenditure  Hepatitis_B  Measles  \
# 1715              0     0.01                0.000000         99.0        0
# 2216              0     0.01                0.000000         69.0        0
# 2409             26     0.00                0.000000         31.0      878
# 2410             26     0.00               46.074469          0.0      441
# 2411             26     0.00               47.444530          0.0      525
# 2412             26     0.00               38.338232          0.0     1952
# 2413             27     0.00                0.000000          0.0     1256
# 2414             27     0.00                0.000000          0.0        0
# 2415             27     0.00                0.000000          0.0        0
# 2416             27     0.00                0.000000          0.0        0
# 2417             27     0.00                0.000000          0.0        0
# 2418             28     0.00                0.000000          0.0        0
# 2419             28     0.00                0.000000          0.0        0
# 2420             29     0.00                0.000000          0.0        0
# 2421             29     0.00                0.000000          0.0        0
# 2422             30     0.00                0.000000          0.0        0
# 2423             30     0.00                0.000000          0.0        0
# 2424             31     0.00                0.000000          0.0        0
# 2457             58     0.00                0.000000         93.0     3585
# 2458             59     0.01              253.608651         94.0      676
# 2459             60     0.01              227.835321         93.0     2813
# 2460             61     0.01              220.522192         92.0     8523
# 2461             61     2.12              196.689215         93.0     5616
# 2462             62     1.77              172.009788         75.0      680
# 2463             63     1.99               17.053693         72.0       68
# 2464             64     2.01              128.636271         78.0      129
# 2465             65     2.01               86.131669         78.0      327
# 2466             66     1.90               60.336857          6.0      228
# 2467             66     1.55               37.590396         22.0     1374
# 2468             68     1.59               37.044800          0.0     9562
# 2469             69     1.74               35.352647          0.0     4381
# 2470             70     1.59               30.622875          0.0     4529
# 2471             71     1.81               28.880697          0.0     4362
# 2472             71     1.76               30.860010          0.0     2875
#
#       ...  Polio  Total_expenditure  Diphtheria  HIV/AIDS          GDP  \
# 1715  ...   99.0               4.30        99.0       0.1     0.000000
# 2216  ...   69.0               6.50        69.0       0.1     0.000000
# 2409  ...   41.0               0.00        31.0       3.4   758.725782
# 2410  ...   44.0               2.74        39.0       3.5  1151.861715
# 2411  ...    5.0               2.62        45.0       3.6  1186.113250
# 2412  ...   64.0               2.77        59.0       3.8   958.455810
# 2413  ...   66.0               0.00        61.0       3.9   176.971300
# 2414  ...    0.0               0.00         0.0       4.0  1562.239346
# 2415  ...    0.0               0.00         0.0       4.2  1264.789980
# 2416  ...    0.0               0.00         0.0       4.2  1678.711862
# 2417  ...    0.0               0.00         0.0       4.2     0.000000
# 2418  ...    0.0               0.00         0.0       4.1     0.000000
# 2419  ...    0.0               0.00         0.0       3.9     0.000000
# 2420  ...    0.0               0.00         0.0       3.8     0.000000
# 2421  ...    0.0               0.00         0.0       3.5     0.000000
# 2422  ...    0.0               0.00         0.0       3.3     0.000000
# 2423  ...    0.0               0.00         0.0       3.0     0.000000
# 2424  ...    0.0               0.00         0.0       2.7     0.000000
# 2457  ...   93.0               0.00        93.0       0.3  2513.884661
# 2458  ...   94.0               8.43        94.0       0.3  2176.898290
# 2459  ...   93.0               8.42        93.0       0.3  1955.667990
# 2460  ...   92.0               8.20        92.0       0.3  1892.894352
# 2461  ...   93.0               8.30        93.0       0.3  1666.857757
# 2462  ...    9.0               7.97         9.0       0.3  1476.478870
# 2463  ...   81.0               8.40        81.0       0.3  1226.884381
# 2464  ...   85.0               8.17        86.0       0.3  1291.528826
# 2465  ...   84.0               4.72        84.0       0.3  1115.695200
# 2466  ...   77.0               3.93        78.0       0.2   893.879364
# 2467  ...   78.0               3.18        78.0       0.2   679.753995
# 2468  ...   74.0               3.39        74.0       0.2   565.569459
# 2469  ...   69.0               3.18        69.0       0.2   477.738478
# 2470  ...    6.0               2.95         6.0       0.2   412.151756
# 2471  ...   66.0               2.96        66.0       0.2   377.525445
# 2472  ...   62.0               3.23        62.0       0.1   361.358430
#
#       Population  thinness__1_19_years  thinness_5_9_years  \
# 1715         0.0                   0.0                 0.0
# 2216         0.0                   0.0                 0.0
# 2409  11882136.0                   0.0                 0.0
# 2410   1153971.0                   0.0                 0.0
# 2411   1117749.0                   0.0                 0.0
# 2412   1818258.0                   0.0                 0.0
# 2413   1448857.0                   0.0                 0.0
# 2414    167192.0                   0.0                 0.0
# 2415    967667.0                   0.0                 0.0
# 2416   9263136.0                   0.0                 0.0
# 2417     88568.0                   0.0                 0.0
# 2418   8468152.0                   0.0                 0.0
# 2419    818877.0                   0.0                 0.0
# 2420   7787655.0                   0.0                 0.0
# 2421    751642.0                   0.0                 0.0
# 2422   7237276.0                   0.0                 0.0
# 2423   6974442.0                   0.0                 0.0
# 2424     67656.0                   0.0                 0.0
# 2457   3864783.0                   0.0                 0.0
# 2458  37737913.0                   0.0                 0.0
# 2459  36849918.0                   0.0                 0.0
# 2460   3599192.0                   0.0                 0.0
# 2461  35167314.0                   0.0                 0.0
# 2462  34385963.0                   0.0                 0.0
# 2463   3365619.0                   0.0                 0.0
# 2464  32955496.0                   0.0                 0.0
# 2465  32282526.0                   0.0                 0.0
# 2466    316764.0                   0.0                 0.0
# 2467   3911914.0                   0.0                 0.0
# 2468   3186341.0                   0.0                 0.0
# 2469  29435944.0                   0.0                 0.0
# 2470  28679565.0                   0.0                 0.0
# 2471    279455.0                   0.0                 0.0
# 2472   2725535.0                   0.0                 0.0
#
#       Income_composition_of_resources  Schooling
# 1715                            0.000        0.0
# 2216                            0.000       15.1
# 2409                            0.421        4.9
# 2410                            0.421        4.9
# 2411                            0.417        4.9
# 2412                            0.419        4.9
# 2413                            0.429        4.9
# 2414                            0.000        0.0
# 2415                            0.000        0.0
# 2416                            0.000        0.0
# 2417                            0.000        0.0
# 2418                            0.000        0.0
# 2419                            0.000        0.0
# 2420                            0.000        0.0
# 2421                            0.000        0.0
# 2422                            0.000        0.0
# 2423                            0.000        0.0
# 2424                            0.000        0.0
# 2457                            0.488        7.2
# 2458                            0.485        7.2
# 2459                            0.478        7.0
# 2460                            0.468        6.8
# 2461                            0.463        7.0
# 2462                            0.461        7.0
# 2463                            0.456        6.8
# 2464                            0.444        6.3
# 2465                            0.440        6.4
# 2466                            0.430        6.2
# 2467                            0.423        6.1
# 2468                            0.415        5.7
# 2469                            0.409        5.6
# 2470                            0.403        5.6
# 2471                            0.399        5.6
# 2472                            0.394        5.5
#
# [34 rows x 22 columns]

# %%
q_low = df['BMI'].quantile(0.1)
q_high = df['BMI'].quantile(0.99)

print(q_low, q_high)
# Out:
# 6.8 72.063

# %%
df = df[(df.BMI > q_low) & (df.BMI < q_high) & (df.Life_expectancy > 0)]
df
# Out:
#           Country  Year      Status  Life_expectancy  Adult_Mortality  \
# 0     Afghanistan  2015  Developing             65.0            263.0
# 1     Afghanistan  2014  Developing             59.9            271.0
# 2     Afghanistan  2013  Developing             59.9            268.0
# 3     Afghanistan  2012  Developing             59.5            272.0
# 4     Afghanistan  2011  Developing             59.2            275.0
# ...           ...   ...         ...              ...              ...
# 2933     Zimbabwe  2004  Developing             44.3            723.0
# 2934     Zimbabwe  2003  Developing             44.5            715.0
# 2935     Zimbabwe  2002  Developing             44.8             73.0
# 2936     Zimbabwe  2001  Developing             45.3            686.0
# 2937     Zimbabwe  2000  Developing             46.0            665.0
#
#       infant_deaths  Alcohol  percentage_expenditure  Hepatitis_B  Measles  \
# 0                62     0.01               71.279624         65.0     1154
# 1                64     0.01               73.523582         62.0      492
# 2                66     0.01               73.219243         64.0      430
# 3                69     0.01               78.184215         67.0     2787
# 4                71     0.01                7.097109         68.0     3013
# ...             ...      ...                     ...          ...      ...
# 2933             27     4.36                0.000000         68.0       31
# 2934             26     4.06                0.000000          7.0      998
# 2935             25     4.43                0.000000         73.0      304
# 2936             25     1.72                0.000000         76.0      529
# 2937             24     1.68                0.000000         79.0     1483
#
#       ...  Polio  Total_expenditure  Diphtheria  HIV/AIDS         GDP  \
# 0     ...    6.0               8.16        65.0       0.1  584.259210
# 1     ...   58.0               8.18        62.0       0.1  612.696514
# 2     ...   62.0               8.13        64.0       0.1  631.744976
# 3     ...   67.0               8.52        67.0       0.1  669.959000
# 4     ...   68.0               7.87        68.0       0.1   63.537231
# ...   ...    ...                ...         ...       ...         ...
# 2933  ...   67.0               7.13        65.0      33.6  454.366654
# 2934  ...    7.0               6.52        68.0      36.7  453.351155
# 2935  ...   73.0               6.53        71.0      39.8   57.348340
# 2936  ...   76.0               6.16        75.0      42.1  548.587312
# 2937  ...   78.0               7.10        78.0      43.5  547.358878
#
#       Population  thinness__1_19_years  thinness_5_9_years  \
# 0     33736494.0                  17.2                17.3
# 1       327582.0                  17.5                17.5
# 2     31731688.0                  17.7                17.7
# 3      3696958.0                  17.9                18.0
# 4      2978599.0                  18.2                18.2
# ...          ...                   ...                 ...
# 2933  12777511.0                   9.4                 9.4
# 2934  12633897.0                   9.8                 9.9
# 2935    125525.0                   1.2                 1.3
# 2936  12366165.0                   1.6                 1.7
# 2937  12222251.0                  11.0                11.2
#
#       Income_composition_of_resources  Schooling
# 0                               0.479       10.1
# 1                               0.476       10.0
# 2                               0.470        9.9
# 3                               0.463        9.8
# 4                               0.454        9.5
# ...                               ...        ...
# 2933                            0.407        9.2
# 2934                            0.418        9.5
# 2935                            0.427       10.0
# 2936                            0.427        9.8
# 2937                            0.434        9.8
#
# [2611 rows x 22 columns]

# %%
sns.histplot(data=df, x='BMI',y='Life_expectancy')
# Out:
# <AxesSubplot:xlabel='BMI', ylabel='Life_expectancy'>

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(),annot=True,cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %%
raw_df.isna().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
df[['Hepatitis_B','Polio']]
# Out:
#       Hepatitis_B  Polio
# 0            65.0    6.0
# 1            62.0   58.0
# 2            64.0   62.0
# 3            67.0   67.0
# 4            68.0   68.0
# ...           ...    ...
# 2933         68.0   67.0
# 2934          7.0    7.0
# 2935         73.0   73.0
# 2936         76.0   76.0
# 2937         79.0   78.0
#
# [2611 rows x 2 columns]

# %%
df[df.Hepatitis_B == df.Polio]
# Out:
#           Country  Year      Status  Life_expectancy  Adult_Mortality  \
# 3     Afghanistan  2012  Developing             59.5            272.0
# 4     Afghanistan  2011  Developing             59.2            275.0
# 5     Afghanistan  2010  Developing             58.8            279.0
# 6     Afghanistan  2009  Developing             58.6            281.0
# 7     Afghanistan  2008  Developing             58.1            287.0
# ...           ...   ...         ...              ...              ...
# 2906       Zambia  2015  Developing             61.8             33.0
# 2929     Zimbabwe  2008  Developing             48.2            632.0
# 2934     Zimbabwe  2003  Developing             44.5            715.0
# 2935     Zimbabwe  2002  Developing             44.8             73.0
# 2936     Zimbabwe  2001  Developing             45.3            686.0
#
#       infant_deaths  Alcohol  percentage_expenditure  Hepatitis_B  Measles  \
# 3                69     0.01               78.184215         67.0     2787
# 4                71     0.01                7.097109         68.0     3013
# 5                74     0.01               79.679367         66.0     1989
# 6                77     0.01               56.762217         63.0     2861
# 7                80     0.03               25.873925         64.0     1599
# ...             ...      ...                     ...          ...      ...
# 2906             27     0.00                0.000000          9.0        9
# 2929             30     3.56               20.843429         75.0        0
# 2934             26     4.06                0.000000          7.0      998
# 2935             25     4.43                0.000000         73.0      304
# 2936             25     1.72                0.000000         76.0      529
#
#       ...  Polio  Total_expenditure  Diphtheria  HIV/AIDS          GDP  \
# 3     ...   67.0               8.52        67.0       0.1   669.959000
# 4     ...   68.0               7.87        68.0       0.1    63.537231
# 5     ...   66.0               9.20        66.0       0.1   553.328940
# 6     ...   63.0               9.42        63.0       0.1   445.893298
# 7     ...   64.0               8.33        64.0       0.1   373.361116
# ...   ...    ...                ...         ...       ...          ...
# 2906  ...    9.0               0.00         9.0       4.1  1313.889646
# 2929  ...   75.0               4.96        75.0      20.5   325.678573
# 2934  ...    7.0               6.52        68.0      36.7   453.351155
# 2935  ...   73.0               6.53        71.0      39.8    57.348340
# 2936  ...   76.0               6.16        75.0      42.1   548.587312
#
#       Population  thinness__1_19_years  thinness_5_9_years  \
# 3      3696958.0                  17.9                18.0
# 4      2978599.0                  18.2                18.2
# 5      2883167.0                  18.4                18.4
# 6       284331.0                  18.6                18.7
# 7      2729431.0                  18.8                18.9
# ...          ...                   ...                 ...
# 2906    161587.0                   6.3                 6.1
# 2929  13558469.0                   7.8                 7.8
# 2934  12633897.0                   9.8                 9.9
# 2935    125525.0                   1.2                 1.3
# 2936  12366165.0                   1.6                 1.7
#
#       Income_composition_of_resources  Schooling
# 3                               0.463        9.8
# 4                               0.454        9.5
# 5                               0.448        9.2
# 6                               0.434        8.9
# 7                               0.433        8.7
# ...                               ...        ...
# 2906                            0.576       12.5
# 2929                            0.421        9.7
# 2934                            0.418        9.5
# 2935                            0.427       10.0
# 2936                            0.427        9.8
#
# [744 rows x 22 columns]

# %%
df_difference = pd.DataFrame()
df_difference['Hepatitis_B'] = df['Hepatitis_B']
df_difference['Polio'] = df['Polio']
df_difference['difference'] = abs(df['Hepatitis_B'] - df['Polio'])

# %%
df_difference[(df_difference['difference'] > 0) & (df_difference['difference'] < 10)]
# Out:
#       Hepatitis_B  Polio  difference
# 1            62.0   58.0         4.0
# 2            64.0   62.0         2.0
# 9            64.0   58.0         6.0
# 10           66.0   58.0         8.0
# 24           98.0   99.0         1.0
# ...           ...    ...         ...
# 2930         72.0   73.0         1.0
# 2931         68.0   71.0         3.0
# 2932         65.0   69.0         4.0
# 2933         68.0   67.0         1.0
# 2937         79.0   78.0         1.0
#
# [1045 rows x 3 columns]

# %%
Heppatitis_B = []
for index,row in df.iterrows():
    if int(row['Hepatitis_B']) == 0:
        Heppatitis_B.append(row['Polio'])
    else:
        Heppatitis_B.append(row['Hepatitis_B'])

# %%
Heppatitis_B
# Out:
# [65.0,
#  62.0,
#  64.0,
#  67.0,
#  68.0,
#  66.0,
#  63.0,
#  64.0,
#  63.0,
#  64.0,
#  66.0,
#  67.0,
#  65.0,
#  64.0,
#  63.0,
#  62.0,
#  99.0,
#  98.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  98.0,
#  99.0,
#  98.0,
#  98.0,
#  99.0,
#  97.0,
#  96.0,
#  96.0,
#  96.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  94.0,
#  91.0,
#  8.0,
#  83.0,
#  81.0,
#  87.0,
#  86.0,
#  89.0,
#  86.0,
#  64.0,
#  64.0,
#  77.0,
#  75.0,
#  72.0,
#  61.0,
#  69.0,
#  73.0,
#  36.0,
#  39.0,
#  4.0,
#  4.0,
#  37.0,
#  41.0,
#  3.0,
#  99.0,
#  99.0,
#  99.0,
#  98.0,
#  99.0,
#  98.0,
#  98.0,
#  98.0,
#  97.0,
#  99.0,
#  99.0,
#  99.0,
#  96.0,
#  96.0,
#  94.0,
#  94.0,
#  94.0,
#  91.0,
#  94.0,
#  94.0,
#  9.0,
#  85.0,
#  84.0,
#  88.0,
#  81.0,
#  73.0,
#  66.0,
#  85.0,
#  88.0,
#  94.0,
#  93.0,
#  95.0,
#  95.0,
#  95.0,
#  94.0,
#  85.0,
#  78.0,
#  91.0,
#  91.0,
#  93.0,
#  91.0,
#  69.0,
#  55.0,
#  93.0,
#  91.0,
#  91.0,
#  91.0,
#  92.0,
#  92.0,
#  94.0,
#  94.0,
#  94.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  94.0,
#  9.0,
#  93.0,
#  98.0,
#  95.0,
#  92.0,
#  89.0,
#  86.0,
#  83.0,
#  83.0,
#  85.0,
#  83.0,
#  86.0,
#  83.0,
#  83.0,
#  81.0,
#  96.0,
#  94.0,
#  88.0,
#  84.0,
#  8.0,
#  74.0,
#  68.0,
#  62.0,
#  52.0,
#  49.0,
#  5.0,
#  51.0,
#  5.0,
#  77.0,
#  75.0,
#  95.0,
#  96.0,
#  97.0,
#  96.0,
#  95.0,
#  98.0,
#  93.0,
#  96.0,
#  93.0,
#  93.0,
#  88.0,
#  89.0,
#  21.0,
#  91.0,
#  98.0,
#  98.0,
#  99.0,
#  99.0,
#  98.0,
#  97.0,
#  97.0,
#  98.0,
#  98.0,
#  98.0,
#  98.0,
#  98.0,
#  99.0,
#  97.0,
#  97.0,
#  97.0,
#  96.0,
#  94.0,
#  96.0,
#  94.0,
#  97.0,
#  96.0,
#  95.0,
#  86.0,
#  45.0,
#  11.0,
#  5.0,
#  83.0,
#  97.0,
#  94.0,
#  91.0,
#  87.0,
#  91.0,
#  93.0,
#  85.0,
#  93.0,
#  84.0,
#  92.0,
#  93.0,
#  91.0,
#  66.0,
#  18.0,
#  86.0,
#  99.0,
#  97.0,
#  98.0,
#  98.0,
#  96.0,
#  98.0,
#  98.0,
#  91.0,
#  98.0,
#  99.0,
#  99.0,
#  56.0,
#  99.0,
#  93.0,
#  7.0,
#  98.0,
#  98.0,
#  98.0,
#  98.0,
#  97.0,
#  97.0,
#  97.0,
#  98.0,
#  94.0,
#  64.0,
#  64.0,
#  6.0,
#  6.0,
#  6.0,
#  95.0,
#  98.0,
#  95.0,
#  96.0,
#  97.0,
#  94.0,
#  96.0,
#  98.0,
#  96.0,
#  97.0,
#  96.0,
#  97.0,
#  96.0,
#  82.0,
#  78.0,
#  77.0,
#  8.0,
#  75.0,
#  76.0,
#  79.0,
#  75.0,
#  82.0,
#  74.0,
#  73.0,
#  15.0,
#  77.0,
#  78.0,
#  99.0,
#  99.0,
#  97.0,
#  97.0,
#  95.0,
#  93.0,
#  96.0,
#  95.0,
#  95.0,
#  95.0,
#  89.0,
#  95.0,
#  83.0,
#  89.0,
#  98.0,
#  99.0,
#  98.0,
#  94.0,
#  95.0,
#  91.0,
#  93.0,
#  88.0,
#  84.0,
#  83.0,
#  85.0,
#  84.0,
#  8.0,
#  77.0,
#  77.0,
#  77.0,
#  82.0,
#  89.0,
#  91.0,
#  92.0,
#  88.0,
#  89.0,
#  9.0,
#  88.0,
#  94.0,
#  9.0,
#  36.0,
#  87.0,
#  86.0,
#  92.0,
#  87.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  94.0,
#  94.0,
#  93.0,
#  93.0,
#  92.0,
#  91.0,
#  9.0,
#  88.0,
#  86.0,
#  96.0,
#  96.0,
#  96.0,
#  96.0,
#  98.0,
#  96.0,
#  99.0,
#  99.0,
#  99.0,
#  98.0,
#  96.0,
#  97.0,
#  92.0,
#  91.0,
#  94.0,
#  99.0,
#  98.0,
#  99.0,
#  93.0,
#  96.0,
#  96.0,
#  96.0,
#  97.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  92.0,
#  95.0,
#  95.0,
#  95.0,
#  96.0,
#  95.0,
#  96.0,
#  96.0,
#  95.0,
#  96.0,
#  94.0,
#  96.0,
#  88.0,
#  93.0,
#  94.0,
#  91.0,
#  91.0,
#  88.0,
#  9.0,
#  91.0,
#  91.0,
#  92.0,
#  93.0,
#  89.0,
#  76.0,
#  94.0,
#  83.0,
#  83.0,
#  69.0,
#  62.0,
#  45.0,
#  94.0,
#  95.0,
#  96.0,
#  96.0,
#  96.0,
#  96.0,
#  94.0,
#  92.0,
#  99.0,
#  92.0,
#  87.0,
#  83.0,
#  75.0,
#  74.0,
#  72.0,
#  71.0,
#  83.0,
#  76.0,
#  8.0,
#  82.0,
#  62.0,
#  85.0,
#  81.0,
#  74.0,
#  76.0,
#  77.0,
#  76.0,
#  67.0,
#  1.0,
#  66.0,
#  96.0,
#  94.0,
#  94.0,
#  9.0,
#  98.0,
#  98.0,
#  98.0,
#  96.0,
#  95.0,
#  93.0,
#  91.0,
#  66.0,
#  4.0,
#  91.0,
#  9.0,
#  89.0,
#  88.0,
#  83.0,
#  86.0,
#  88.0,
#  89.0,
#  92.0,
#  91.0,
#  82.0,
#  8.0,
#  82.0,
#  86.0,
#  69.0,
#  54.0,
#  59.0,
#  62.0,
#  84.0,
#  87.0,
#  89.0,
#  85.0,
#  82.0,
#  84.0,
#  8.0,
#  84.0,
#  82.0,
#  81.0,
#  79.0,
#  72.0,
#  72.0,
#  66.0,
#  61.0,
#  55.0,
#  55.0,
#  55.0,
#  7.0,
#  7.0,
#  56.0,
#  42.0,
#  28.0,
#  14.0,
#  14.0,
#  14.0,
#  88.0,
#  88.0,
#  88.0,
#  47.0,
#  47.0,
#  23.0,
#  47.0,
#  42.0,
#  46.0,
#  46.0,
#  47.0,
#  47.0,
#  45.0,
#  44.0,
#  42.0,
#  4.0,
#  38.0,
#  46.0,
#  37.0,
#  39.0,
#  4.0,
#  33.0,
#  39.0,
#  24.0,
#  17.0,
#  38.0,
#  49.0,
#  37.0,
#  31.0,
#  36.0,
#  31.0,
#  26.0,
#  3.0,
#  97.0,
#  95.0,
#  9.0,
#  9.0,
#  94.0,
#  94.0,
#  95.0,
#  92.0,
#  95.0,
#  92.0,
#  94.0,
#  96.0,
#  97.0,
#  96.0,
#  91.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  95.0,
#  92.0,
#  91.0,
#  84.0,
#  79.0,
#  75.0,
#  7.0,
#  65.0,
#  91.0,
#  9.0,
#  91.0,
#  92.0,
#  85.0,
#  88.0,
#  92.0,
#  92.0,
#  93.0,
#  93.0,
#  89.0,
#  92.0,
#  78.0,
#  8.0,
#  78.0,
#  91.0,
#  88.0,
#  88.0,
#  89.0,
#  83.0,
#  74.0,
#  83.0,
#  69.0,
#  68.0,
#  77.0,
#  28.0,
#  98.0,
#  7.0,
#  7.0,
#  8.0,
#  9.0,
#  85.0,
#  62.0,
#  7.0,
#  74.0,
#  75.0,
#  73.0,
#  64.0,
#  73.0,
#  62.0,
#  67.0,
#  32.0,
#  31.0,
#  91.0,
#  94.0,
#  91.0,
#  84.0,
#  89.0,
#  87.0,
#  89.0,
#  89.0,
#  88.0,
#  89.0,
#  86.0,
#  94.0,
#  8.0,
#  89.0,
#  94.0,
#  95.0,
#  96.0,
#  98.0,
#  97.0,
#  97.0,
#  95.0,
#  96.0,
#  96.0,
#  96.0,
#  95.0,
#  95.0,
#  94.0,
#  94.0,
#  99.0,
#  96.0,
#  96.0,
#  96.0,
#  96.0,
#  96.0,
#  95.0,
#  93.0,
#  89.0,
#  95.0,
#  99.0,
#  99.0,
#  98.0,
#  98.0,
#  96.0,
#  96.0,
#  96.0,
#  96.0,
#  96.0,
#  96.0,
#  93.0,
#  93.0,
#  93.0,
#  88.0,
#  88.0,
#  88.0,
#  88.0,
#  89.0,
#  89.0,
#  97.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  98.0,
#  99.0,
#  86.0,
#  97.0,
#  98.0,
#  96.0,
#  93.0,
#  93.0,
#  96.0,
#  93.0,
#  92.0,
#  92.0,
#  96.0,
#  92.0,
#  98.0,
#  27.0,
#  99.0,
#  98.0,
#  93.0,
#  81.0,
#  8.0,
#  74.0,
#  6.0,
#  72.0,
#  65.0,
#  7.0,
#  62.0,
#  6.0,
#  52.0,
#  47.0,
#  4.0,
#  3.0,
#  42.0,
#  93.0,
#  94.0,
#  94.0,
#  94.0,
#  91.0,
#  9.0,
#  89.0,
#  88.0,
#  87.0,
#  93.0,
#  93.0,
#  95.0,
#  96.0,
#  98.0,
#  97.0,
#  97.0,
#  84.0,
#  78.0,
#  82.0,
#  81.0,
#  87.0,
#  88.0,
#  89.0,
#  88.0,
#  64.0,
#  68.0,
#  62.0,
#  49.0,
#  46.0,
#  81.0,
#  89.0,
#  8.0,
#  74.0,
#  8.0,
#  83.0,
#  8.0,
#  81.0,
#  84.0,
#  87.0,
#  82.0,
#  79.0,
#  63.0,
#  66.0,
#  68.0,
#  78.0,
#  83.0,
#  87.0,
#  88.0,
#  88.0,
#  93.0,
#  94.0,
#  96.0,
#  92.0,
#  88.0,
#  82.0,
#  75.0,
#  69.0,
#  36.0,
#  93.0,
#  97.0,
#  93.0,
#  96.0,
#  97.0,
#  97.0,
#  97.0,
#  98.0,
#  98.0,
#  98.0,
#  97.0,
#  98.0,
#  97.0,
#  99.0,
#  91.0,
#  93.0,
#  92.0,
#  92.0,
#  89.0,
#  89.0,
#  91.0,
#  98.0,
#  89.0,
#  9.0,
#  94.0,
#  81.0,
#  75.0,
#  99.0,
#  16.0,
#  2.0,
#  3.0,
#  3.0,
#  39.0,
#  59.0,
#  57.0,
#  55.0,
#  48.0,
#  46.0,
#  44.0,
#  43.0,
#  41.0,
#  95.0,
#  94.0,
#  94.0,
#  94.0,
#  96.0,
#  9.0,
#  92.0,
#  94.0,
#  91.0,
#  94.0,
#  96.0,
#  84.0,
#  91.0,
#  86.0,
#  89.0,
#  82.0,
#  91.0,
#  93.0,
#  93.0,
#  94.0,
#  94.0,
#  94.0,
#  95.0,
#  94.0,
#  95.0,
#  95.0,
#  95.0,
#  9.0,
#  95.0,
#  94.0,
#  94.0,
#  93.0,
#  77.0,
#  77.0,
#  72.0,
#  69.0,
#  65.0,
#  62.0,
#  56.0,
#  52.0,
#  47.0,
#  59.0,
#  56.0,
#  54.0,
#  55.0,
#  55.0,
#  55.0,
#  55.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  98.0,
#  97.0,
#  98.0,
#  98.0,
#  99.0,
#  99.0,
#  97.0,
#  97.0,
#  97.0,
#  97.0,
#  96.0,
#  96.0,
#  95.0,
#  95.0,
#  96.0,
#  86.0,
#  83.0,
#  74.0,
#  78.0,
#  51.0,
#  47.0,
#  42.0,
#  39.0,
#  35.0,
#  35.0,
#  28.0,
#  29.0,
#  28.0,
#  26.0,
#  8.0,
#  7.0,
#  79.0,
#  82.0,
#  75.0,
#  67.0,
#  79.0,
#  82.0,
#  75.0,
#  52.0,
#  44.0,
#  44.0,
#  44.0,
#  44.0,
#  97.0,
#  96.0,
#  97.0,
#  98.0,
#  96.0,
#  97.0,
#  97.0,
#  98.0,
#  97.0,
#  95.0,
#  94.0,
#  92.0,
#  91.0,
#  91.0,
#  94.0,
#  91.0,
#  96.0,
#  92.0,
#  89.0,
#  95.0,
#  54.0,
#  94.0,
#  84.0,
#  79.0,
#  64.0,
#  48.0,
#  51.0,
#  61.0,
#  55.0,
#  88.0,
#  88.0,
#  88.0,
#  88.0,
#  88.0,
#  88.0,
#  87.0,
#  86.0,
#  87.0,
#  9.0,
#  88.0,
#  9.0,
#  87.0,
#  86.0,
#  84.0,
#  88.0,
#  98.0,
#  9.0,
#  92.0,
#  91.0,
#  94.0,
#  94.0,
#  93.0,
#  94.0,
#  84.0,
#  84.0,
#  8.0,
#  8.0,
#  88.0,
#  96.0,
#  96.0,
#  98.0,
#  98.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  95.0,
#  94.0,
#  92.0,
#  92.0,
#  91.0,
#  9.0,
#  89.0,
#  92.0,
#  97.0,
#  97.0,
#  97.0,
#  94.0,
#  97.0,
#  99.0,
#  99.0,
#  96.0,
#  91.0,
#  83.0,
#  97.0,
#  98.0,
#  96.0,
#  97.0,
#  73.0,
#  85.0,
#  96.0,
#  88.0,
#  94.0,
#  92.0,
#  95.0,
#  85.0,
#  89.0,
#  87.0,
#  88.0,
#  84.0,
#  82.0,
#  78.0,
#  54.0,
#  51.0,
#  63.0,
#  62.0,
#  63.0,
#  57.0,
#  57.0,
#  53.0,
#  59.0,
#  65.0,
#  61.0,
#  56.0,
#  52.0,
#  47.0,
#  87.0,
#  87.0,
#  87.0,
#  87.0,
#  86.0,
#  83.0,
#  8.0,
#  77.0,
#  76.0,
#  69.0,
#  ...]

# %%
df.Hepatitis_B = Heppatitis_B

# %%
df[df.Hepatitis_B == 0]
# Out:
#           Country  Year      Status  Life_expectancy  Adult_Mortality  \
# 1742   Montenegro  2005  Developing             73.6            133.0
# 1743   Montenegro  2004  Developing             73.5            134.0
# 1744   Montenegro  2003  Developing             73.5            134.0
# 1745   Montenegro  2002  Developing             73.4            136.0
# 1746   Montenegro  2001  Developing             73.3            136.0
# 1747   Montenegro  2000  Developing             73.0            144.0
# 2615  Timor-Leste  2001  Developing             59.4            269.0
# 2616  Timor-Leste  2000  Developing             58.7            276.0
#
#       infant_deaths  Alcohol  percentage_expenditure  Hepatitis_B  Measles  \
# 1742              0     0.00              527.307672          0.0        0
# 1743              0     0.01               57.121901          0.0        0
# 1744              0     0.01              495.078296          0.0        0
# 1745              0     0.01               36.480240          0.0        0
# 1746              0     0.01               33.669814          0.0        0
# 1747              0     0.01              274.547260          0.0        0
# 2615              3     0.50                6.556583          0.0        0
# 2616              3     0.50               49.069672          0.0        0
#
#       ...  Polio  Total_expenditure  Diphtheria  HIV/AIDS          GDP  \
# 1742  ...    0.0               8.46         0.0       0.1  3674.617924
# 1743  ...    0.0               8.45         0.0       0.1   338.199535
# 1744  ...    0.0               8.91         0.0       0.1  2789.173500
# 1745  ...    0.0               8.33         0.0       0.1   216.243274
# 1746  ...    0.0               8.23         0.0       0.1   199.583957
# 1747  ...    0.0               7.32         0.0       0.1  1627.428930
# 2615  ...    0.0               3.75         0.0       0.1    56.424987
# 2616  ...    0.0               3.26         0.0       0.1   422.286330
#
#       Population  thinness__1_19_years  thinness_5_9_years  \
# 1742    614261.0                   2.3                 2.3
# 1743    613353.0                   2.3                 2.4
# 1744    612267.0                   2.4                 2.4
# 1745     69828.0                   2.5                 2.5
# 1746     67389.0                   2.5                 2.6
# 1747      6495.0                   2.6                 2.7
# 2615    892531.0                  12.1                12.2
# 2616     87167.0                  12.2                12.2
#
#       Income_composition_of_resources  Schooling
# 1742                            0.746       12.8
# 1743                            0.740       12.6
# 1744                            0.000        0.0
# 1745                            0.000        0.0
# 1746                            0.000        0.0
# 1747                            0.000        0.0
# 2615                            0.470        9.8
# 2616                            0.000        0.0
#
# [8 rows x 22 columns]

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(),annot=True,cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %% [markdown]
# Does various predicting factors which has been chosen initially really affect the Life expectancy? What are the predicting variables actually affecting the life expectancy?
#
# -BMI
# -Thinness 1-19
# -GDP
# -Schooling

# %%
X = df.drop("Life_expectancy",axis=1)
y = df["Life_expectancy"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=0)

X_train.shape, X_test.shape
# Out:
# ((1827, 21), (784, 21))

# %%
plt.figure(figsize=(15,15))
sns.heatmap(X_train.corr(),annot=True,cmap=plt.cm.CMRmap_r)
# Out:
# <AxesSubplot:>

# %%
def correlation(dataset, threshold):
    col_corr = set()
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if (corr_matrix.iloc[i, j]) > threshold:
                colname = corr_matrix.columns[i]
                col_corr.add(colname)
    return col_corr

# %%
corr_features = correlation(X_train, 0.8)
len(set(corr_features))
# Out:
# 4

# %%
corr_features
# Out:
# {'GDP', 'Schooling', 'thinness_5_9_years', 'under_five_deaths'}

# %%
X_train.drop(corr_features,axis=1)
X_test.drop(corr_features,axis=1)
# Out:
#          Country  Year      Status  Adult_Mortality  infant_deaths  Alcohol  \
# 2289  Seychelles  2007  Developing            185.0              0     8.12
# 2724      Uganda  2005  Developing            446.0             99    10.09
# 210     Barbados  2013  Developing             11.0              0     8.74
# 2849     Vanuatu  2008  Developing            153.0              0     1.18
# 1005     Germany  2004   Developed             86.0              3    11.83
# ...          ...   ...         ...              ...            ...      ...
# 2056    Portugal  2014   Developed             78.0              0     9.88
# 582     Colombia  2009  Developing             15.0             13     4.34
# 800      Ecuador  2001  Developing            158.0              9     4.13
# 1607    Maldives  2010  Developing             73.0              0     1.83
# 1741  Montenegro  2006  Developing             13.0              0     5.38
#
#       percentage_expenditure  Hepatitis_B  Measles   BMI  Polio  \
# 2289              916.474177         99.0        1  31.2   99.0
# 2724               44.526140         64.0       22  14.5   59.0
# 210               263.037284         91.0        0  53.0   91.0
# 2849              345.339056         61.0        0  47.4   66.0
# 1005             5842.374765         88.0      121  57.1   96.0
# ...                      ...          ...      ...   ...    ...
# 2056              271.254553         98.0        0   6.9   98.0
# 582               941.646405         92.0        0  53.5   92.0
# 800                14.588740         69.0        2  44.3    9.0
# 1607               91.139718         97.0        0  22.1   97.0
# 1741              595.730692          9.0        0  56.5    9.0
#
#       Total_expenditure  Diphtheria  HIV/AIDS  Population  \
# 2289               3.30        99.0       0.1      8533.0
# 2724               9.36        64.0       8.7   2854394.0
# 210                7.57        91.0       0.1         0.0
# 2849               3.66        67.0       0.1     22534.0
# 1005               1.37        96.0       0.1   8251626.0
# ...                 ...         ...       ...         ...
# 2056               9.50        98.0       0.1     14162.0
# 582                7.10        92.0       0.1  45416181.0
# 800                3.86        89.0       0.3  12852755.0
# 1607               7.93        96.0       0.1       367.0
# 1741               8.10         9.0       0.1     61525.0
#
#       thinness__1_19_years  Income_composition_of_resources
# 2289                   5.9                            0.733
# 2724                   6.5                            0.429
# 210                    3.8                            0.792
# 2849                   1.5                            0.582
# 1005                   1.1                            0.877
# ...                    ...                              ...
# 2056                   0.7                            0.837
# 582                    2.2                            0.691
# 800                    1.6                            0.670
# 1607                  14.0                            0.653
# 1741                   2.2                            0.751
#
# [784 rows x 17 columns]
